# %%
from sqlalchemy import create_engine
source_engine = create_engine(f'sqlite:///source/olist.sqlite')
target_engine = create_engine(f'postgresql://postgres:admin@localhost:5432/e-commerce_dw')

# %%
try:
    with source_engine.connect() as conn:
        print("✅ Successfully connected to SQLite Source")
except Exception as e:
    print(f"❌ SQLite Connection Error: {e}")

try:
    with target_engine.connect() as conn:
        print("✅ Successfully connected to PostgreSQL DW")
except Exception as e:
    print(f"❌ PostgreSQL Connection Error: {e}")
# Out:
# ✅ Successfully connected to SQLite Source
# ✅ Successfully connected to PostgreSQL DW
